# %%
import numpy as np
import gym
from gym import spaces
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from collections import deque
import random
import shap


# Абстрактный роутер
class AbstractRouter:
    def __init__(self, router_id, neighbors=None, speed=10):
        self.router_id = router_id
        # self.config = {'ip': f'192.168.1.{router_id}', 'subnet': '255.255.255.0'}
        self.traffic = 0
        self.max_capacity = 100  # Максимальная пропускная способность
        self.speed = speed  # Пропускная способность
        self.is_active = True  # Состояние роутера
        self.neighbors = neighbors or []  # Список соседей

    def configure(self, config):
        if self.is_active:
            self.max_capacity = config["max_capacity"]
            self.speed = config["speed"]

    def receive_traffic(self, amount):
        if not self.is_active:
            return 0
        self.traffic = amount
        if int(self.traffic) > int(self.max_capacity):
            self.is_active = False  # Роутер "падает" под нагрузкой
        return self.traffic

    def forward_traffic(self):
        if not self.is_active or not self.neighbors:
            return []
        # Отправляем трафик соседям с учетом пропускной способности
        forward_amount = min(self.traffic, self.speed)
        traffic_per_neighbor = forward_amount / len(self.neighbors)
        self.traffic -= forward_amount
        return [(neighbor, traffic_per_neighbor) for neighbor in self.neighbors]

    def get_status(self):
        return {
            'router_id': self.router_id,
            'traffic': self.traffic,
            'max_capacity': self.max_capacity,
            'speed': self.speed,
            'is_active': self.is_active,
            'neighbors': self.neighbors,
        }


# Сеть маршрутизаторов
class Network:
    def __init__(self, routers=None, target_server=None):
        self.routers = {router.router_id: router for router in routers} if routers else {}
        self.target_server = target_server  # Целевой сервер

    def add_router(self, router):
        self.routers[router.router_id] = router

    def configure_router(self, router_id, config):
        if router_id in self.routers:
            self.routers[router_id].configure(config)

    def send_traffic(self, router_id, amount):
        if router_id in self.routers:
            return self.routers[router_id].receive_traffic(amount)
        return amount

    def forward_traffic(self):
        for router in self.routers.values():
            forwarded_traffic = router.forward_traffic()
            for neighbor_id, traffic in forwarded_traffic:
                if neighbor_id in self.routers:
                    self.routers[neighbor_id].receive_traffic(traffic)

    def is_network_active(self):
        is_line_active = list()
        is_active = True
        for router in self.routers.values():
            if router.get_status()['router_id'] == self.target_server:
                continue
            if router.get_status()['is_active'] == False:
                is_active = False
            if self.target_server in router.get_status()['neighbors']:
                is_line_active.append(is_active)
                is_active = True
        if (not(any(is_line_active))):
          print([r.get_status() for r in self.routers.values()])
        return any(is_line_active)


    def get_router_status(self, router_id):
        if router_id in self.routers:
            return self.routers[router_id].get_status()
        return None

    def get_network_status(self):
        return {router_id: router.get_status() for router_id, router in self.routers.items()}


# Синий агент
class BlueAgent:
    def __init__(self, num_routers):
        self.num_routers = num_routers
        self.model = self.build_model()
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.mean_losses = []
        self.mean_rewards = []

    def build_model(self):
        model = keras.Sequential([
            layers.Dense(64, activation='relu', input_dim=self.num_routers),
            layers.Dense(64, activation='relu'),
            layers.Dense(self.num_routers * 2, activation='sigmoid')  # Акции для каждого маршрутизатора
        ])
        model.compile(optimizer='adam', loss='mse')
        return model

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.randint(0, 100, size=self.num_routers * 2).reshape((self.num_routers, 2))
        # Преобразуем состояние в правильную форму для передачи в модель (добавляем размерность для батча)
        action = self.model.predict(state)
        print(action)
        return action.reshape((self.num_routers, 2))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def clean_memory(self):
        self.memory = deque(maxlen=2000)

    def replay(self, batch_size):
        batch_size = min(batch_size, len(self.memory))
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)

            mean_loss = np.mean(np.square(target_f - self.model.predict(state)))
            mean_reward = np.mean([reward for _, _, reward, _, _ in minibatch])
            self.mean_losses.append(mean_loss)
            self.mean_rewards.append(mean_reward)

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def explain_with_shap(self, state):
        explainer = shap.KernelExplainer(self.model.predict, np.zeros((1, self.num_routers)))
        shap_values = explainer.shap_values(state[0])

        # Визуализация
        print("SHAP values for Blue Agent:")
        shap.summary_plot(shap_values, feature_names=[f"Router {i}" for i in range(self.num_routers)])


# Красный агент
class RedAgent:
    def __init__(self, max_traffic=50):
        self.max_traffic = max_traffic
        self.model = self.build_model()
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.mean_losses = []
        self.mean_rewards = []

    def build_model(self):
        model = keras.Sequential([
            layers.Dense(64, activation='relu', input_dim=3),
            layers.Dense(64, activation='relu'),
            layers.Dense(3, activation='linear')  # Трафик для каждого маршрутизатора
        ])
        model.compile(optimizer='adam', loss='mse')
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def clean_memory(self):
        self.memory = deque(maxlen=2000)

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.randint(0, 50, size=3).reshape(1, 3)
        action = self.model.predict(state)
        print(np.clip(action, 0, 50))
        return np.clip(action, 0, 50) # TODO: ограничивать общий трафик а не на один роутер

    def replay(self, batch_size):
        batch_size = min(batch_size, len(self.memory))
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)

            mean_loss = np.mean(np.square(target_f - self.model.predict(state)))
            mean_reward = np.mean([reward for _, _, reward, _, _ in minibatch])
            self.mean_losses.append(mean_loss)
            self.mean_rewards.append(mean_reward)

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def explain_with_shap(self, state):
        explainer = shap.KernelExplainer(self.model.predict, np.zeros((1, 3)))  # 3 маршрутизатора
        shap_values = explainer.shap_values(state[0])
        # Визуализация
        print("SHAP values for Red Agent:")

        shap.summary_plot(shap_values, feature_names=["Router A", "Router B", "Router C"])


# Среда для взаимодействия агентов
class NetworkEnv(gym.Env):
    def __init__(self, num_routers=9, max_capacity=100):
        super(NetworkEnv, self).__init__()
        self.num_routers = num_routers
        self.max_capacity = max_capacity
        self.target_server = num_routers - 1
        self.is_active_sum = num_routers

        # Создаем маршрутизаторы с независимыми путями
        self.routers = [
            AbstractRouter(i, neighbors=[], speed=np.random.randint(5, 15)) for i in range(num_routers)
        ]

        # Настроим три независимые линии маршрутизаторов
        # Линия 1
        self.routers[0].neighbors = [1]
        self.routers[1].neighbors = [2]
        self.routers[2].neighbors = [self.target_server]

        # Линия 2
        self.routers[3].neighbors = [4]
        self.routers[4].neighbors = [5]
        self.routers[5].neighbors = [self.target_server]

        # Линия 3
        self.routers[6].neighbors = [7]
        self.routers[7].neighbors = [8]
        self.routers[8].neighbors = [self.target_server]

        self.network = Network(self.routers, target_server=self.target_server)

        # Пространство состояний
        self.observation_space = spaces.Dict({
            'router_status': spaces.Box(low=0, high=max_capacity, shape=(num_routers,), dtype=np.float32),
            'is_active': spaces.MultiBinary(num_routers),
        })

        # Пространство действий
        self.blue_action_space = spaces.Box(low=0, high=255, shape=(num_routers, 2), dtype=np.float32)
        self.red_action_space = spaces.Box(low=0, high=50, shape=(3,), dtype=np.float32)  # Красный агент выбирает 3 маршрутизатора

    def step(self, blue_action, red_action):
        for i, config in enumerate(blue_action):
            self.network.configure_router(
                i, {'max_capacity': config[0], 'speed': config[1]}
            )
        # Применяем действия красного агента
        self.network.send_traffic(0, red_action[0][0])
        self.network.send_traffic(3, red_action[0][1])
        self.network.send_traffic(6, red_action[0][2])
        bonus_reward = 0

        # Передаем трафик по сети
        self.network.forward_traffic()

        # Проверяем состояние сети
        network_status = self.network.get_network_status()
        router_status = np.array([status['traffic'] for status in network_status.values()])
        is_active = np.array([1 if status['is_active'] else 0 for status in network_status.values()])
        if sum(is_active) < self.is_active_sum:
            bonus_reward = 50 * (self.is_active_sum - sum(is_active))
            self.is_active_sum = sum(is_active)
        done = not(self.network.is_network_active())

        # Награды
        self.root_server_traffic = self.routers[self.target_server].traffic
        self.routers[self.target_server].traffic = 0  # Очищаем трафик у корневого сервера

        blue_reward = self.root_server_traffic - bonus_reward  # Награда за доставку данных
        red_reward = -self.root_server_traffic + bonus_reward  # Штраф за доставку данных

        # Состояние сети
        red_state = [self.routers[0].traffic, self.routers[3].traffic, self.routers[6].traffic]
        blue_state = [r.traffic for r in self.routers]
        observation = {'router_status': router_status, 'is_active': is_active}


        return (observation, red_state), (blue_reward, red_reward), done, {}

    def reset(self):
        # Создаем маршрутизаторы с независимыми путями
        self.routers = [
            AbstractRouter(i, neighbors=[], speed=np.random.randint(5, 15)) for i in range(self.num_routers)
        ]

        # Настроим три независимые линии маршрутизаторов
        # Линия 1
        self.routers[0].neighbors = [1]
        self.routers[1].neighbors = [2]
        self.routers[2].neighbors = [self.target_server]

        # Линия 2
        self.routers[3].neighbors = [4]
        self.routers[4].neighbors = [5]
        self.routers[5].neighbors = [self.target_server]

        # Линия 3
        self.routers[6].neighbors = [7]
        self.routers[7].neighbors = [8]
        self.routers[8].neighbors = [self.target_server]

        self.network = Network(self.routers, target_server=self.target_server)

        # Пространство состояний
        self.observation_space = spaces.Dict({
            'router_status': spaces.Box(low=0, high=self.max_capacity, shape=(self.num_routers,), dtype=np.float32),
            'is_active': spaces.MultiBinary(self.num_routers),
        })

        # Пространство действий
        self.blue_action_space = spaces.Box(low=0, high=255, shape=(self.num_routers, 2), dtype=np.float32)
        self.red_action_space = spaces.Box(low=0, high=50, shape=(3,), dtype=np.float32)


        router_status = np.array([0 for _ in self.routers])
        is_active = np.array([1 for _ in self.routers])

        return {'router_status': router_status, 'is_active': is_active}




if __name__ == "__main__":
    env = NetworkEnv(num_routers=9, max_capacity=100)
    blue_agent = BlueAgent(num_routers=env.num_routers)
    red_agent = RedAgent()

    num_episodes = 100
    max_steps = 150

    for episode in range(num_episodes):
        observation = env.reset()
        print(f"\nЭпизод {episode + 1}")

        for step in range(max_steps):
            blue_state = np.expand_dims(observation['router_status'], axis=0)
            red_state = np.expand_dims(np.array([0, 0, 0]), axis=0)

            blue_action = blue_agent.act(blue_state)
            red_action = red_agent.act(red_state)

            states, rewards, done, _ = env.step(blue_action, red_action)

            blue_agent.remember(blue_state, blue_action, rewards[0], np.expand_dims(states[0]['router_status'], axis=0), done)
            red_agent.remember(red_state, red_action, rewards[1], np.expand_dims(states[1], axis=0), done)

            print(f"Шаг {step + 1}: Награды (Blue, Red): {rewards}")

            '''
            # Вызов функций объяснения действий агентов
            print(f"Объяснение действий синего агента на шаге {step + 1}:")
            blue_agent.explain_with_shap(blue_state)

            print(f"Объяснение действий красного агента на шаге {step + 1}:")
            red_agent.explain_with_shap(red_state)
            '''

            if done:
                print("Сеть упала! Завершаем эпизод.")
                break

        print("Обучение агентов...")
        blue_agent.replay(batch_size=32)
        red_agent.replay(batch_size=32)
        blue_agent.clean_memory()
        red_agent.clean_memory()

    print("Все эпизоды завершены.")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Эпизод 1
# Шаг 1: Награды (Blue, Red): (-33.0, 33.0)
# [{'router_id': 0, 'traffic': 0, 'max_capacity': 87, 'speed': 89, 'is_active': True, 'neighbors': [1]}, {'router_id': 1, 'traffic': 17.0, 'max_capacity': 62, 'speed': 32, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 32.0, 'max_capacity': 8, 'speed': 7, 'is_active': False, 'neighbors': [8]}, {'router_id': 3, 'traffic': 21, 'max_capacity': 19, 'speed': 27, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 55, 'speed': 69, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 60, 'speed': 17, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 23, 'max_capacity': 2, 'speed': 93, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 31.0, 'max_capacity': 27, 'speed': 12, 'is_active': False, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 31, 'speed': 34, 'is_active': True, 'neighbors': [8]}]
# Шаг 2: Награды (Blue, Red): (-150.0, 150.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 2
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# Шаг 2: Награды (Blue, Red): (7.0, -7.0)
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# [{'router_id': 0, 'traffic': 46, 'max_capacity': 15, 'speed': 89, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 57, 'speed': 74, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 47, 'speed': 95, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 12, 'max_capacity': 5, 'speed': 11, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 38.0, 'max_capacity': 36, 'speed': 67, 'is_active': False, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0, 'max_capacity': 33, 'speed': 6, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 0, 'max_capacity': 76, 'speed': 68, 'is_active': True, 'neighbors': [7]}, {'router_id': 7, 'traffic': 29.0, 'max_capacity': 14, 'speed': 2, 'is_active': False, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 56, 'speed': 67, 'is_active': True, 'neighbors': [8]}]
# Шаг 4: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 3
# Шаг 1: Награды (Blue, Red): (7.0, -7.0)
# Шаг 2: Награды (Blue, Red): (6.0, -6.0)
# Шаг 3: Награды (Blue, Red): (0, 0)
# [{'router_id': 0, 'traffic': 46, 'max_capacity': 40, 'speed': 81, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 7, 'speed': 97, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 94, 'speed': 81, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 0, 'max_capacity': 77, 'speed': 92, 'is_active': True, 'neighbors': [4]}, {'router_id': 4, 'traffic': 28.0, 'max_capacity': 5, 'speed': 4, 'is_active': False, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 84, 'speed': 60, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 0, 'max_capacity': 77, 'speed': 60, 'is_active': True, 'neighbors': [7]}, {'router_id': 7, 'traffic': 30.0, 'max_capacity': 11, 'speed': 16, 'is_active': False, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0, 'max_capacity': 1, 'speed': 18, 'is_active': False, 'neighbors': [8]}]
# Шаг 4: Награды (Blue, Red): (0, 0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Эпизод 4
# Шаг 1: Награды (Blue, Red): (6.0, -6.0)
# Шаг 2: Награды (Blue, Red): (1.0, -1.0)
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# Шаг 4: Награды (Blue, Red): (0.0, 0.0)
# [{'router_id': 0, 'traffic': 30, 'max_capacity': 2, 'speed': 33, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0, 'max_capacity': 91, 'speed': 99, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 87, 'speed': 70, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 0, 'max_capacity': 42, 'speed': 71, 'is_active': True, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 40, 'speed': 31, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 25.0, 'max_capacity': 8, 'speed': 78, 'is_active': False, 'neighbors': [8]}, {'router_id': 6, 'traffic': 37, 'max_capacity': 32, 'speed': 20, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0.0, 'max_capacity': 19, 'speed': 18, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 16, 'speed': 78, 'is_active': True, 'neighbors': [8]}]
# Шаг 5: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Эпизод 5
# [{'router_id': 0, 'traffic': 0, 'max_capacity': 59, 'speed': 94, 'is_active': True, 'neighbors': [1]}, {'router_id': 1, 'traffic': 38.0, 'max_capacity': 1, 'speed': 91, 'is_active': False, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0, 'max_capacity': 79, 'speed': 96, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 31, 'max_capacity': 30, 'speed': 17, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0, 'max_capacity': 86, 'speed': 34, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 98, 'speed': 71, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 0, 'max_capacity': 73, 'speed': 56, 'is_active': True, 'neighbors': [7]}, {'router_id': 7, 'traffic': 26.0, 'max_capacity': 9, 'speed': 81, 'is_active': False, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 24, 'speed': 26, 'is_active': True, 'neighbors': [8]}]
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 6
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# [{'router_id': 0, 'traffic': 12, 'max_capacity': 0, 'speed': 71, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 90, 'speed': 79, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 70, 'speed': 27, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 0, 'max_capacity': 68, 'speed': 76, 'is_active': True, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 41, 'speed': 45, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 39.0, 'max_capacity': 23, 'speed': 66, 'is_active': False, 'neighbors': [8]}, {'router_id': 6, 'traffic': 45, 'max_capacity': 15, 'speed': 89, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0, 'max_capacity': 86, 'speed': 87, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 7, 'speed': 29, 'is_active': True, 'neighbors': [8]}]
# Шаг 4: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Эпизод 7
# Шаг 1: Награды (Blue, Red): (6.0, -6.0)
# Шаг 2: Награды (Blue, Red): (7.0, -7.0)
# Шаг 3: Награды (Blue, Red): (12.0, -12.0)
# Шаг 4: Награды (Blue, Red): (-33.0, 33.0)
# Шаг 5: Награды (Blue, Red): (0, 0)
# [{'router_id': 0, 'traffic': 37, 'max_capacity': 31, 'speed': 77, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 31.0, 'max_capacity': 6, 'speed': 49, 'is_active': False, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 28, 'speed': 46, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 48, 'max_capacity': 9, 'speed': 37, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 30, 'speed': 89, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 1, 'speed': 47, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 42, 'max_capacity': 38, 'speed': 15, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 28.0, 'max_capacity': 17, 'speed': 67, 'is_active': False, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0, 'max_capacity': 13, 'speed': 63, 'is_active': False, 'neighbors': [8]}]
# Шаг 6: Награды (Blue, Red): (-50, 50)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Эпизод 8
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# Шаг 2: Награды (Blue, Red): (36.0, -36.0)
# [{'router_id': 0, 'traffic': 36, 'max_capacity': 17, 'speed': 18, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 87, 'speed': 52, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 67, 'speed': 93, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 0, 'max_capacity': 18, 'speed': 61, 'is_active': True, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 29, 'speed': 42, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 9.0, 'max_capacity': 0, 'speed': 46, 'is_active': False, 'neighbors': [8]}, {'router_id': 6, 'traffic': 11, 'max_capacity': 6, 'speed': 74, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0, 'max_capacity': 85, 'speed': 56, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0, 'max_capacity': 24, 'speed': 32, 'is_active': False, 'neighbors': [8]}]
# Шаг 3: Награды (Blue, Red): (0, 0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 9
# Шаг 1: Награды (Blue, Red): (8.0, -8.0)
# Шаг 2: Награды (Blue, Red): (4.0, -4.0)
# [{'router_id': 0, 'traffic': 12, 'max_capacity': 85, 'speed': 11, 'is_active': True, 'neighbors': [1]}, {'router_id': 1, 'traffic': 7.0, 'max_capacity': 3, 'speed': 16, 'is_active': False, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0, 'max_capacity': 54, 'speed': 97, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 41, 'max_capacity': 13, 'speed': 10, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 27.0, 'max_capacity': 71, 'speed': 7, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 39, 'speed': 78, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 26, 'max_capacity': 11, 'speed': 13, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 41.0, 'max_capacity': 36, 'speed': 16, 'is_active': False, 'neighbors': [8]}, {'router_id': 8, 'traffic': 7.0, 'max_capacity': 49, 'speed': 62, 'is_active': True, 'neighbors': [8]}]
# Шаг 3: Награды (Blue, Red): (7.0, -7.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Эпизод 10
# Шаг 1: Награды (Blue, Red): (8.0, -8.0)
# [{'router_id': 0, 'traffic': 8, 'max_capacity': 34, 'speed': 2, 'is_active': True, 'neighbors': [1]}, {'router_id': 1, 'traffic': 29.0, 'max_capacity': 11, 'speed': 5, 'is_active': False, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0, 'max_capacity': 96, 'speed': 12, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 36, 'max_capacity': 30, 'speed': 49, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0, 'max_capacity': 99, 'speed': 34, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 19, 'speed': 73, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 41, 'max_capacity': 34, 'speed': 89, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0.0, 'max_capacity': 36, 'speed': 23, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0, 'max_capacity': 2, 'speed': 57, 'is_active': False, 'neighbors': [8]}]
# Шаг 2: Награды (Blue, Red): (0, 0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 11
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.49840775 0.49840775 0.49840775 0.49840775 0.49840775 0.49840775
#   0.49840775 0.49840775 0.49840775 0.49840775 0.49840775 0.49840775
#   0.49840775 0.49840775 0.49840775 0.49840775 0.49840775 0.49840775]]
# [{'router_id': 0, 'traffic': 6, 'max_capacity': 0.49840775, 'speed': 0.49840775, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 36.0, 'max_capacity': 10, 'speed': 80, 'is_active': False, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0, 'max_capacity': 0.49840775, 'speed': 0.49840775, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 49, 'max_capacity': 0.49840775, 'speed': 0.49840775, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 0.49840775, 'speed': 0.49840775, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 0.49840775, 'speed': 0.49840775, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 13, 'max_capacity': 12, 'speed': 3, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0, 'max_capacity': 0.49840775, 'speed': 0.49840775, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 0.49840775, 'speed': 0.49840775, 'is_active': True, 'neighbors': [8]}]
# Шаг 4: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 12
# Шаг 1: Награды (Blue, Red): (34.0, -34.0)
# Шаг 2: Награды (Blue, Red): (29.0, -29.0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# [[0.00666636 0.00666636 0.00666636]]
# Шаг 3: Награды (Blue, Red): (0, 0)
# Шаг 4: Награды (Blue, Red): (0, 0)
# [{'router_id': 0, 'traffic': 47, 'max_capacity': 30, 'speed': 95, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0, 'max_capacity': 48, 'speed': 19, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 37, 'speed': 34, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 4, 'max_capacity': 3, 'speed': 70, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0, 'max_capacity': 35, 'speed': 40, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 52, 'speed': 3, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 27, 'max_capacity': 12, 'speed': 44, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0.0, 'max_capacity': 33, 'speed': 70, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0, 'max_capacity': 14, 'speed': 75, 'is_active': False, 'neighbors': [8]}]
# Шаг 5: Награды (Blue, Red): (0, 0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Эпизод 13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.00604529 0.00604529 0.00604529]]
# Шаг 1: Награды (Blue, Red): (0.006045287940651178, -0.006045287940651178)
# Шаг 2: Награды (Blue, Red): (2.0, -2.0)
# [{'router_id': 0, 'traffic': 0, 'max_capacity': 46, 'speed': 45, 'is_active': True, 'neighbors': [1]}, {'router_id': 1, 'traffic': 14.0, 'max_capacity': 6, 'speed': 11, 'is_active': False, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 35, 'speed': 47, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 45, 'max_capacity': 23, 'speed': 26, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 63, 'speed': 83, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 96, 'speed': 99, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 18, 'max_capacity': 14, 'speed': 19, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0.0, 'max_capacity': 39, 'speed': 96, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 6, 'speed': 59, 'is_active': True, 'neighbors': [8]}]
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
#
# Эпизод 14
# Шаг 1: Награды (Blue, Red): (9.0, -9.0)
# Шаг 2: Награды (Blue, Red): (24.0, -24.0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.00546976 0.00546976 0.00546976]]
# Шаг 3: Награды (Blue, Red): (0.005469758994877338, -0.005469758994877338)
# Шаг 4: Награды (Blue, Red): (16.0, -16.0)
# [{'router_id': 0, 'traffic': 21, 'max_capacity': 6, 'speed': 75, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 36, 'speed': 84, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 62, 'speed': 26, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 34, 'max_capacity': 6, 'speed': 6, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0, 'max_capacity': 15, 'speed': 85, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 98, 'speed': 69, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 46, 'max_capacity': 12, 'speed': 37, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0.0, 'max_capacity': 27, 'speed': 50, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0, 'max_capacity': 9, 'speed': 7, 'is_active': False, 'neighbors': [8]}]
# Шаг 5: Награды (Blue, Red): (0, 0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Эпизод 15
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# [{'router_id': 0, 'traffic': 0, 'max_capacity': 89, 'speed': 39, 'is_active': True, 'neighbors': [1]}, {'router_id': 1, 'traffic': 39.0, 'max_capacity': 0, 'speed': 28, 'is_active': False, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 34, 'speed': 29, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 19, 'max_capacity': 7, 'speed': 93, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 34, 'speed': 65, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 60, 'speed': 59, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 47, 'max_capacity': 36, 'speed': 72, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0, 'max_capacity': 80, 'speed': 81, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 44, 'speed': 21, 'is_active': True, 'neighbors': [8]}]
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Эпизод 16
# Шаг 1: Награды (Blue, Red): (30.0, -30.0)
# [{'router_id': 0, 'traffic': 46, 'max_capacity': 35, 'speed': 44, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0, 'max_capacity': 78, 'speed': 99, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 24, 'speed': 64, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 31, 'max_capacity': 21, 'speed': 32, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0, 'max_capacity': 54, 'speed': 5, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 47, 'speed': 64, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 0, 'max_capacity': 96, 'speed': 42, 'is_active': True, 'neighbors': [7]}, {'router_id': 7, 'traffic': 22.0, 'max_capacity': 2, 'speed': 55, 'is_active': False, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0, 'max_capacity': 16, 'speed': 96, 'is_active': False, 'neighbors': [8]}]
# Шаг 2: Награды (Blue, Red): (0, 0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 17
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# [{'router_id': 0, 'traffic': 0, 'max_capacity': 39, 'speed': 81, 'is_active': True, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 72, 'speed': 34, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 23.0, 'max_capacity': 9, 'speed': 96, 'is_active': False, 'neighbors': [8]}, {'router_id': 3, 'traffic': 42, 'max_capacity': 37, 'speed': 32, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0, 'max_capacity': 32, 'speed': 9, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 78, 'speed': 71, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 13, 'max_capacity': 0, 'speed': 45, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0, 'max_capacity': 44, 'speed': 44, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 81, 'speed': 85, 'is_active': True, 'neighbors': [8]}]
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Эпизод 18
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.00315728 0.00315728 0.00315728]]
# Шаг 4: Награды (Blue, Red): (0.0, 0.0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.00315728 0.00315728 0.00315728]]
# Шаг 5: Награды (Blue, Red): (0.0, 0.0)
# Шаг 6: Награды (Blue, Red): (0.0, 0.0)
# [{'router_id': 0, 'traffic': 23, 'max_capacity': 20, 'speed': 95, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 23, 'speed': 41, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 69, 'speed': 40, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 46, 'max_capacity': 24, 'speed': 63, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 29, 'speed': 59, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 17.0, 'max_capacity': 13, 'speed': 8, 'is_active': False, 'neighbors': [8]}, {'router_id': 6, 'traffic': 44, 'max_capacity': 37, 'speed': 77, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0, 'max_capacity': 54, 'speed': 89, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 74, 'speed': 14, 'is_active': True, 'neighbors': [8]}]
# Шаг 7: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# [[0.00232496 0.00232496 0.00232496]]
# Шаг 1: Награды (Blue, Red): (0.00232496066018939, -0.00232496066018939)
# Шаг 2: Награды (Blue, Red): (11.0, -11.0)
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# Шаг 4: Награды (Blue, Red): (12.0, -12.0)
# [{'router_id': 0, 'traffic': 18, 'max_capacity': 13, 'speed': 33, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 38, 'speed': 79, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 12, 'speed': 10, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 0, 'max_capacity': 83, 'speed': 66, 'is_active': True, 'neighbors': [4]}, {'router_id': 4, 'traffic': 36.0, 'max_capacity': 23, 'speed': 2, 'is_active': False, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 72, 'speed': 66, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 22, 'max_capacity': 20, 'speed': 10, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0.0, 'max_capacity': 9, 'speed': 84, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0, 'max_capacity': 0, 'speed': 89, 'is_active': False, 'neighbors': [8]}]
# Шаг 5: Награды (Blue, Red): (0, 0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Эпизод 20
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# [{'router_id': 0, 'traffic': 35, 'max_capacity': 15, 'speed': 78, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 6, 'speed': 17, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 91, 'speed': 2, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 0, 'max_capacity': 37, 'speed': 93, 'is_active': True, 'neighbors': [4]}, {'router_id': 4, 'traffic': 36.0, 'max_capacity': 19, 'speed': 48, 'is_active': False, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0, 'max_capacity': 82, 'speed': 48, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 0, 'max_capacity': 91, 'speed': 52, 'is_active': True, 'neighbors': [7]}, {'router_id': 7, 'traffic': 37.0, 'max_capacity': 1, 'speed': 29, 'is_active': False, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 40, 'speed': 90, 'is_active': True, 'neighbors': [8]}]
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 21
# Шаг 1: Награды (Blue, Red): (20.0, -20.0)
# Шаг 2: Награды (Blue, Red): (24.0, -24.0)
# Шаг 3: Награды (Blue, Red): (26.0, -26.0)
# Шаг 4: Награды (Blue, Red): (0, 0)
# Шаг 5: Награды (Blue, Red): (0, 0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# [[0.0014823 0.0014823 0.0014823]]
# Шаг 6: Награды (Blue, Red): (0, 0)
# Шаг 7: Награды (Blue, Red): (0, 0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# [[0.0014823 0.0014823 0.0014823]]
# Шаг 8: Награды (Blue, Red): (0, 0)
# [{'router_id': 0, 'traffic': 42, 'max_capacity': 36, 'speed': 32, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0, 'max_capacity': 42, 'speed': 4, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 13, 'speed': 40, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 48, 'max_capacity': 44, 'speed': 75, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 32.0, 'max_capacity': 31, 'speed': 65, 'is_active': False, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0, 'max_capacity': 60, 'speed': 62, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 24, 'max_capacity': 4, 'speed': 68, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0.0, 'max_capacity': 88, 'speed': 97, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0, 'max_capacity': 15, 'speed': 70, 'is_active': False, 'neighbors': [8]}]
# Шаг 9: Награды (Blue, Red): (0, 0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Эпизод 22
# Шаг 1: Награды (Blue, Red): (7.0, -7.0)
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# [{'router_id': 0, 'traffic': 28, 'max_capacity': 12, 'speed': 77, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 39, 'speed': 77, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 18, 'speed': 45, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 38, 'max_capacity': 17, 'speed': 73, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 99, 'speed': 80, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 26, 'speed': 68, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 35, 'max_capacity': 16, 'speed': 69, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0.0, 'max_capacity': 22, 'speed': 6, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 87, 'speed': 58, 'is_active': True, 'neighbors': [8]}]
# Шаг 4: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Эпизод 23
# Шаг 1: Награды (Blue, Red): (0.0, 0.0)
# [{'router_id': 0, 'traffic': 9, 'max_capacity': 33, 'speed': 0, 'is_active': True, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 43, 'speed': 49, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 25.0, 'max_capacity': 5, 'speed': 9, 'is_active': False, 'neighbors': [8]}, {'router_id': 3, 'traffic': 31, 'max_capacity': 14, 'speed': 99, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0.0, 'max_capacity': 95, 'speed': 94, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 41, 'speed': 71, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 20, 'max_capacity': 6, 'speed': 85, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0, 'max_capacity': 17, 'speed': 9, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 53, 'speed': 21, 'is_active': True, 'neighbors': [8]}]
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Эпизод 24
# Шаг 1: Награды (Blue, Red): (26.0, -26.0)
# [{'router_id': 0, 'traffic': 36, 'max_capacity': 91, 'speed': 3, 'is_active': True, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0.0, 'max_capacity': 9, 'speed': 19, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 14.0, 'max_capacity': 8, 'speed': 77, 'is_active': False, 'neighbors': [8]}, {'router_id': 3, 'traffic': 39, 'max_capacity': 37, 'speed': 16, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0, 'max_capacity': 69, 'speed': 3, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 76, 'speed': 27, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 20, 'max_capacity': 84, 'speed': 6, 'is_active': True, 'neighbors': [7]}, {'router_id': 7, 'traffic': 6.0, 'max_capacity': 1, 'speed': 63, 'is_active': False, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 14, 'speed': 71, 'is_active': True, 'neighbors': [8]}]
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Эпизод 25
# Шаг 1: Награды (Blue, Red): (25.0, -25.0)
# Шаг 2: Награды (Blue, Red): (16.0, -16.0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0. 0. 0.]]
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# Шаг 4: Награды (Blue, Red): (43.0, -43.0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# [[0.5011914 0.5011914 0.5011914 0.5011914 0.5011914 0.5011914 0.5011914
#   0.5011914 0.5011914 0.5011914 0.5011914 0.5011914 0.5011914 0.5011914
#   0.5011914 0.5011914 0.5011914 0.5011914]]
# ...
# Шаг 2: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Эпизод 77
# Шаг 1: Награды (Blue, Red): (18.0, -18.0)
# Шаг 2: Награды (Blue, Red): (15.0, -15.0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.5121665 0.5121665 0.5121665 0.5121665 0.5121665 0.5121665 0.5121665
#   0.5121665 0.5121665 0.5121665 0.5121665 0.5121665 0.5121665 0.5121665
#   0.5121665 0.5121665 0.5121665 0.5121665]]
# [{'router_id': 0, 'traffic': 23, 'max_capacity': 15, 'speed': 14, 'is_active': False, 'neighbors': [1]}, {'router_id': 1, 'traffic': 0, 'max_capacity': 0.5121665, 'speed': 0.5121665, 'is_active': True, 'neighbors': [2]}, {'router_id': 2, 'traffic': 0.0, 'max_capacity': 0.5121665, 'speed': 0.5121665, 'is_active': True, 'neighbors': [8]}, {'router_id': 3, 'traffic': 40, 'max_capacity': 30, 'speed': 62, 'is_active': False, 'neighbors': [4]}, {'router_id': 4, 'traffic': 0, 'max_capacity': 0.5121665, 'speed': 0.5121665, 'is_active': True, 'neighbors': [5]}, {'router_id': 5, 'traffic': 0.0, 'max_capacity': 0.5121665, 'speed': 0.5121665, 'is_active': True, 'neighbors': [8]}, {'router_id': 6, 'traffic': 35, 'max_capacity': 0.5121665, 'speed': 0.5121665, 'is_active': False, 'neighbors': [7]}, {'router_id': 7, 'traffic': 0.0, 'max_capacity': 0.5121665, 'speed': 0.5121665, 'is_active': True, 'neighbors': [8]}, {'router_id': 8, 'traffic': 0.0, 'max_capacity': 0.5121665, 'speed': 0.5121665, 'is_active': True, 'neighbors': [8]}]
# Шаг 3: Награды (Blue, Red): (0.0, 0.0)
# Сеть упала! Завершаем эпизод.
# Обучение агентов...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-73444fa4f188> in <cell line: 356>()
#     394
#     395         print("Обучение агентов...")
# --> 396         blue_agent.replay(batch_size=32)
#     397         red_agent.replay(batch_size=32)
#     398         blue_agent.clean_memory()
#
# <ipython-input-2-73444fa4f188> in replay(self, batch_size)
#     151             self.model.fit(state, target_f, epochs=1, verbose=0)
#     152
# --> 153             mean_loss = np.mean(np.square(target_f - self.model.predict(state)))
#     154             mean_reward = np.mean([reward for _, _, reward, _, _ in minibatch])
#     155             self.mean_losses.append(mean_loss)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in predict(self, x, batch_size, verbose, steps, callbacks)
#     448     ):
#     449         # Create an iterator that yields batches of input data.
# --> 450         epoch_iterator = TFEpochIterator(
#     451             x=x,
#     452             batch_size=batch_size,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in __init__(self, distribute_strategy, *args, **kwargs)
#     666         super().__init__(*args, **kwargs)
#     667         self._distribute_strategy = distribute_strategy
# --> 668         dataset = self._get_iterator()
#     669         if not isinstance(dataset, tf.distribute.DistributedDataset):
#     670             dataset = self._distribute_strategy.experimental_distribute_dataset(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in _get_iterator(self)
#     675
#     676     def _get_iterator(self):
# --> 677         return self.data_adapter.get_tf_dataset()
#     678
#     679     def enumerate_epoch(self):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/array_data_adapter.py in get_tf_dataset(self)
#     230             return dataset
#     231
# --> 232         indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     233         if shuffle == "batch":
#     234             indices_dataset = indices_dataset.map(tf.random.shuffle)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/dataset_ops.py in flat_map(self, map_func, name)
#    2354     # pylint: disable=g-import-not-at-top,protected-access
#    2355     from tensorflow.python.data.ops import flat_map_op
# -> 2356     return flat_map_op._flat_map(self, map_func, name=name)
#    2357     # pylint: enable=g-import-not-at-top,protected-access
#    2358
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/flat_map_op.py in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#      25
#      26
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/flat_map_op.py in __init__(self, input_dataset, map_func, name)
#      31
#      32     self._input_dataset = input_dataset
# ---> 33     self._map_func = structured_function.StructuredFunctionWrapper(
#      34         map_func, self._transformation_name(), dataset=input_dataset)
#      35     if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     263         fn_factory = trace_tf_function(defun_kwargs)
#     264
# --> 265     self._function = fn_factory()
#     266     # There is no graph to add in eager mode.
#     267     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in get_concrete_function(self, *args, **kwargs)
#    1249   def get_concrete_function(self, *args, **kwargs):
#    1250     # Implements PolymorphicFunction.get_concrete_function.
# -> 1251     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253     return concrete
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219       if self._variable_creation_config is None:
#    1220         initializers = []
# -> 1221         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222         self._initialize_uninitialized_variables(initializers)
#    1223
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     )
#     695     # Force the definition of the function for these arguments
# --> 696     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697         args, kwds, self._variable_creation_config
#     698     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     597         # the function a weak reference to itself to avoid a reference cycle.
#     598         with OptionalXlaContext(compile_with_xla):
# --> 599           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600         return out
#     601
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in wrapped_fn(*args)
#     229       # Note: wrapper_helper will apply autograph based on context.
#     230       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231         ret = wrapper_helper(*args)
#     232         ret = structure.to_tensor_list(self._output_structure, ret)
#     233         return [ops.convert_to_tensor(t) for t in ret]
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in wrapper_helper(*args)
#     159       if not _should_unpack(nested_args):
#     160         nested_args = (nested_args,)
# --> 161       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162       ret = variable_utils.convert_variables_to_tensors(ret)
#     163       if _should_pack(ret):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     688       try:
#     689         with conversion_ctx:
# --> 690           return converted_call(f, args, kwargs, options=options)
#     691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/array_data_adapter.py in slice_batch_indices(indices)
#     158             """
#     159             num_in_full_batch = num_full_batches * batch_size
# --> 160             first_k_indices = tf.slice(indices, [0], [num_in_full_batch])
#     161             first_k_indices = tf.reshape(
#     162                 first_k_indices, [num_full_batches, batch_size]
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py in slice(input_, begin, size, name)
#     988     A `Tensor` the same type as `input_`.
#     989   """
# --> 990   return gen_array_ops._slice(input_, begin, size, name=name)
#     991
#     992
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_array_ops.py in _slice(input, begin, size, name)
#    9839       pass  # Add nodes to the TensorFlow graph.
#    9840   # Add nodes to the TensorFlow graph.
# -> 9841   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9842         "Slice", input=input, begin=begin, size=size, name=name)
#    9843   _result = _outputs[:]
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     776   with g.as_default(), ops.name_scope(name) as scope:
#     777     if fallback:
# --> 778       _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                              keywords, default_type_attr_map, attrs, inputs,
#     780                              input_types)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/op_def_library.py in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     549                 preferred_dtype=default_dtype)
#     550         else:
# --> 551           values = ops.convert_to_tensor(
#     552               values,
#     553               name=input_arg.name,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711   # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712   preferred_dtype = preferred_dtype or dtype_hint
# --> 713   return tensor_conversion_registry.convert(
#     714       value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     250               f"{base_type} returned non-Tensor: {ret!r}",
#     251               name=name))
# --> 252     if dtype and not dtype.is_compatible_with(ret.dtype):
#     253       raise RuntimeError(
#     254           _add_error_prefix(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/dtypes.py in is_compatible_with(self, other)
#     192     return min, max
#     193
# --> 194   def is_compatible_with(self, other):
#     195     """Returns True if the `other` DType will be converted to this DType (TF1).
#     196
#
# KeyboardInterrupt:
